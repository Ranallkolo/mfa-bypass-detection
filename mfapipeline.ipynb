# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Check dataset size first
import os
size = os.path.getsize('/home/da_otcifithom/mfa-bypass-detection/rba-dataset.csv')
print(f"Dataset size: {size / (1024**3):.2f} GB")
# Out:
# Dataset size: 8.43 GB

# %%
# Load just first 10000 rows to inspect structure
df_sample = pd.read_csv(
    '/home/da_otcifithom/mfa-bypass-detection/rba-dataset.csv',
    nrows=10000
)

print("Shape:", df_sample.shape)
print("\nColumns:", df_sample.columns.tolist())
print("\nDtypes:\n", df_sample.dtypes)
print("\nFirst 3 rows:\n", df_sample.head(3))
print("\nMissing values:\n", df_sample.isnull().sum())
# Out:
# Shape: (10000, 16)
#
# Columns: ['index', 'Login Timestamp', 'User ID', 'Round-Trip Time [ms]', 'IP Address', 'Country', 'Region', 'City', 'ASN', 'User Agent String', 'Browser Name and Version', 'OS Name and Version', 'Device Type', 'Login Successful', 'Is Attack IP', 'Is Account Takeover']
#
# Dtypes:
#  index                         int64
# Login Timestamp                 str
# User ID                       int64
# Round-Trip Time [ms]        float64
# IP Address                      str
# Country                         str
# Region                          str
# City                            str
# ASN                           int64
# User Agent String               str
# Browser Name and Version        str
# OS Name and Version             str
# Device Type                     str
# Login Successful               bool
# Is Attack IP                   bool
# Is Account Takeover            bool
# dtype: object
#
# First 3 rows:
# ...
